# %% [markdown]
# # Improving plots I - Coloring

# %% [markdown]
# So far you have learned the basics of plotting data. We've seen that data visualization is a very powerful tool that allows us to communicate a lot of information in a clear and concise way. However, the more information we can

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

iris = sns.load_dataset("iris")
np.unique(iris.species)
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.lmplot('sepal_length', 'sepal_width', data=iris, fit_reg=False)

# %%
sns.scatterplot('sepal_length', 'sepal_width', data=iris, hue='sepal_length',size = "sepal_length", palette = "Blues")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.scatterplot('sepal_length', 'sepal_width', data=iris, hue = 'species', size = "sepal_length", palette = "Set2")

# %%
sns.lmplot('sepal_length', 'sepal_width', data=iris, hue='sepal_length', palette = "Blues", fit_reg=False)._legend.remove()

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", kind="bar", data=titanic)

# %%
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
