# %% [markdown]
# # Improving plots I - Coloring

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn

iris = seaborn.load_dataset("iris")
np.unique(iris.species)
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
cols = {'setosa':1, 'versicolor':2, 'virginica':3}

#plt.scatter(iris.sepal_length, iris.sepal_width, c = iris.species.apply(lambda x: cols[x]), cmap = 'winter')

seaborn.lmplot('sepal_length', 'sepal_width', data=iris, hue='species', fit_reg=False)
